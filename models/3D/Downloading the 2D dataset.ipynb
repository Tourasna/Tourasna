# %%
# !pip install icrawler Pillow -q

import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
    ("Qasr El Nil Lion Statue", "اسد قصر النيل"),
    ("Hanging Church", "الكنيسة المعلقة"),
]

# === إنشاء مجلد الحفظ ===
base_dir = "/content/egypt_landmarks_dataset"
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized.zip")
# Out:
# 📍 Downloading images for: Qasr El Nil Lion Statue
# ERROR:downloader:Response status code 404, file https://as2.ftcdn.net/jpg
# ERROR:downloader:Response status code 400, file https://media.gettyimages.com/id/558029823/photo/lion-statue-on-the-qasr-el-nil-bridge-over-the-nile-river-cairo-al-qahirah-egypt.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Protesters_standing_in_front_of_lion_statues_near_Qasr_El_Nil_Bridge_in_Cairo_during_the_2011_Egyptian_Revolution.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/91/CAIRO._-_Kasr-el-Nil_Bridge_%28n.d.%29_-_front_-_TIMEA.jpg
# ERROR:downloader:Response status code 400, file https://media.istockphoto.com/id/1491986598/photo/lion-statue-qasr-al-nil-in-cairo-egypt.jpg
# ERROR:downloader:Response status code 404, file https://as2.ftcdn.net/v2/jpg
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("Senusret I Obelisk", "المسلة الفرعونية سنوسرت الأول"),
    ("Bab Zuweila", "باب زويلة"),
]

# === إنشاء مجلد الحفظ ===
base_dir = "/content/egypt_landmarks_dataset"
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized3.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized3.zip")
# Out:
# 📍 Downloading images for: Senusret I Obelisk
# ERROR:downloader:Response status code 403, file https://www.researchgate.net/publication/326460537/figure/fig4/AS:649622410260489@1531893460812/Obelisk-of-Senusret-I-at-Heliopolis-Photographed-by-P-Sebah-before-1874-Phot-No39.png
# ERROR:downloader:Response status code 400, file https://media.gettyimages.com/id/640240423/photo/masalla-obelisk-al-matariyyah.jpg
# ERROR:downloader:Response status code 202, file https://www.mediastorehouse.com.au/p/629/obelisk-pharaoh-senusret-i-heliopolis-cairo-18062785.jpg
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image
import shutil

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
    ("October War Panorama", "بانوراما حرب اكتوبر"),
    ("Cairo Tower", "برج القاهرة"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_October_Cairo.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_October_Cairo.zip")
# Out:
# 📍 Downloading images for: October War Panorama
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("تمثال ابراهيم باشا", "Ibrahim Pasha Statue"),
    ("تمثال سعد زغلول", "Saad Zaghloul Statue"),
    ("تمثال سيمون بوليفار", "Simon Bolivar Statue"),
    ("تمثال طلعت حرب", "Talaat Harb Statue"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")


# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized5.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized5.zip")
# Out:
# 📍 Downloading images for: تمثال ابراهيم باشا
# ERROR:downloader:Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a91779be900>: Failed to resolve 'png' ([Errno -2] Name or service not known)")), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://png, error: HTTPSConnectionPool(host='png', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a91779bd460>: Failed to resolve 'png' ([Errno -2] Name or service not known)")), remaining retry times: 1
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("جامع الأزهر", "Al-Azhar Mosque"),
    ("جامع عمرو بن العاص", "Amr Ibn Al-As Mosque"),
    ("دار الأوبرا المصرية", "Cairo Opera House"),
    ("ساعة الجامعة", "Cairo University Clock Tower"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")


# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized6.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized6.zip")
# Out:
# 📍 Downloading images for: جامع الأزهر
# ERROR:downloader:Response status code 403, file https://static.vecteezy.com/system/resources/previews/010/196/418/large_2x/al-azhar-mosque-in-cairo-egypt-photo.jpg
# ERROR:downloader:Response status code 400, file https://media.gettyimages.com/id/536065418/photo/al-azhar-mosque-in-cairo.jpg
# ERROR:downloader:Response status code 400, file https://airial.travel/_next/image?url=https%3A%2F%2Fimages.unsplash.com%2Fphoto-1710659765212-02444386ba37%3Fcrop%3Dentropy%26cs%3Dtinysrgb%26fit%3Dmax%26fm%3Djpg
# ERROR:downloader:Response status code 403, file https://www.researchgate.net/publication/342256723/figure/fig1/AS:11431281085842641@1663908900224/the-main-courtyard-of-al-azhar-mosque-students-at-al-azhar-learnt-in-what-were-called.jpg
# ERROR:downloader:Response status code 403, file https://cdn10.picryl.com/photo/1983/07/01/the-al-azhar-mosque-built-in-969-ad-in-downtown-cairo-exact-date-shot-unknown-3376bc-1024.jpg
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("شجرة مريم", "Virgin Mary Tree"),
    ("قصر البارون", "Baron Empain Palace"),
    ("قصر عائشة فهمي", "Aisha Fahmy Palace"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")


# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized7.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized7.zip")
# Out:
# 📍 Downloading images for: شجرة مريم
# ERROR:downloader:Response status code 403, file https://www.telegraph.co.uk/multimedia/archive/00796/virgin460_796804c.jpg
# ERROR:downloader:Response status code 403, file https://www.roadsideamerica.com/attract/images/ca/CACOL1front.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Tree_of_the_apparition_of_the_Virgin_Mary_5.jpg
# ERROR:downloader:Response status code 403, file https://www.roadsideamerica.com/attract/images/ia/IAPOLmarytree_eryn.jpg
# ERROR:downloader:Response status code 403, file https://www.roadsideamerica.com/attract/images/ut/UTSLCstumpmary_nern.jpg
# ERROR:downloader:Response status code 403, file https://www.roadsideamerica.com/attract/images/nm/NMALBcottonwood_schmitz.jpg
# ERROR:downloader:Response status code 400, file https://media.gettyimages.com/id/1424871511/photo/cairos-virgin-mary-tree-area-reopens-after-restoration-project.jpg
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("مسجد السلطان حسن", "Sultan Hassan Mosque"),
    ("مسجد محمد علي", "Muhammad Ali Mosque"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")


# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized8.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized8.zip")
# Out:
# 📍 Downloading images for: مسجد السلطان حسن
# ERROR:downloader:Response status code 403, file https://smarthistory.org/wp-content/uploads/2021/09/mosque-sultan-hasan-outside-copy.jpg
# ERROR:downloader:Response status code 403, file https://smarthistory.org/wp-content/uploads/2021/09/Mosque-Madrassa_of_Sultan_Hassan_-_Cairo_2-copy.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Sultan-Hassan-Moschee_2015-11-14h.jpg
# ERROR:downloader:Response status code 403, file https://www.lookandlearn.com/history-images/preview/YW/YW049/YW049362V_Mosque-of-Sultan-Hassan-Cairo-Egypt-interior-of-the-courtyard.jpg
# ERROR:downloader:Response status code 403, file https://preview.redd.it/egg0386o4ky21.jpg
# ERROR:downloader:Response status code 403, file https://smarthistory.org/wp-content/uploads/2021/09/iwan-copy.jpg
# ...

# %%
import os
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
     ("هرم خوفو", "Great Pyramid of Khufu"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_resized9.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_resized9.zip")
# Out:
# 📍 Downloading images for: هرم خوفو
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Kheops-Pyramid.jpg
# ERROR:downloader:Response status code 403, file https://www.wattan.net/data/image/794x466/10160128565076289130708673215717.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Khafre%27s_Pyramid343.jpg
# ERROR:downloader:Response status code 403, file https://www.syria.tv/sites/default/files/styles/thumb_/public/2024-10/555_2.jpg
# ...

# %%
import os
import shutil
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعالم السياحية (إنجليزي + عربي) ===
landmarks = [
    ("Sneferu Pyramid", "هرم سنيفرو"),
    ("Solar Boat Museum", "مركب الشمس"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    google_crawler.crawl(keyword=eng_name, max_num=100)
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_Sneferu_SolarBoat.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_Sneferu_SolarBoat.zip")
# Out:
# 📍 Downloading images for: Sneferu Pyramid
# ERROR:downloader:Exception caught when downloading file https://www.egypttoursportal.com/images/2019/07/Bent-Pyramid-Dahshur-Egypt-Tours-Portal.jpg, error: HTTPSConnectionPool(host='www.egypttoursportal.com', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://www.egypttoursportal.com/images/2019/07/Bent-Pyramid-Dahshur-Egypt-Tours-Portal.jpg, error: HTTPSConnectionPool(host='www.egypttoursportal.com', port=443): Read timed out. (read timeout=5), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://www.egypttoursportal.com/images/2019/07/Bent-Pyramid-Dahshur-Egypt-Tours-Portal.jpg, error: HTTPSConnectionPool(host='www.egypttoursportal.com', port=443): Read timed out. (read timeout=5), remaining retry times: 0
# ...

# %%
import os
import shutil
from icrawler.builtin import GoogleImageCrawler
from PIL import Image

# === المعلم السياحي ===
landmarks = [
    ("The Sphinx Statue Inside the Museum", "أبو الهول الداخلي المتحف المصري"),
]

# === إنشاء مجلد جديد ونظيف ===
base_dir = "/content/egypt_landmarks_dataset"
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)  # نحذف أي بيانات قديمة
os.makedirs(base_dir, exist_ok=True)

# === تحميل الصور ===
for eng_name, ar_name in landmarks:
    folder_name = eng_name.replace(" ", "_")
    save_dir = os.path.join(base_dir, folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"\n📍 Downloading images for: {eng_name}")

    google_crawler = GoogleImageCrawler(storage={'root_dir': save_dir})
    # نحمل صور بالإنجليزية
    google_crawler.crawl(keyword=eng_name, max_num=100)
    # وبالعربية
    google_crawler.crawl(keyword=ar_name, max_num=100)

# === تنظيف وتحجيم الصور ===
print("\n🧹 Cleaning and resizing images...")

def clean_and_resize_images(folder_path, target_size=(256, 256)):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.getsize(file_path) < 10 * 1024:  # أقل من 10KB
                os.remove(file_path)
                continue

            img = Image.open(file_path)
            img = img.convert("RGB")
            img = img.resize(target_size, Image.Resampling.LANCZOS)
            img.save(file_path)
        except Exception:
            os.remove(file_path)

for landmark_folder in os.listdir(base_dir):
    clean_and_resize_images(os.path.join(base_dir, landmark_folder))

print("✅ Dataset cleaned, resized, and ready!")

# === ضغط المجلد النهائي ===
# !zip -r egypt_landmarks_dataset_InnerSphinx.zip /content/egypt_landmarks_dataset
print("\n📦 Done! You can now download: egypt_landmarks_dataset_InnerSphinx.zip")
# Out:
# 📍 Downloading images for: The Sphinx Statue Inside the Museum
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Grand_sphinx_de_Tanis_-_Mus%C3%A9e_du_Louvre_Antiquit%C3%A9s_%C3%A9gyptiennes_N_23_%3B_A_23_%3B_Salt_3837.jpg
# ERROR:downloader:Response status code 403, file https://www.inquirer.com/resizer/v2/YDU4ZK4IIRA3JGYNAVKE7MADHE.jpg
# ERROR:downloader:Response status code 406, file https://www.cincinnati.com/gcdn/presto/2019/02/07/PCIN/34f69ce1-0180-4171-8ee6-78a028abb7f5-020719_HATSHEPSUT_05.JPG?width=700&height=467&fit=crop&format=pjpg
# ERROR:downloader:Response status code 403, file https://www.britishmuseum.org/sites/default/files/styles/16_9_media_huge/public/2019-09/the-younger-memnon-statue-british-museum.jpg
# ERROR:downloader:Response status code 404, file https://img.pikbest.com/backgrounds/20250111/arafed-statue-of-a-sphinx-in-museum-with-door-open_11372665.jpg
# ...
